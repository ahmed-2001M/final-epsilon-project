# %%
import pandas as pd
from DB import PostgreSQLConnection

# %%
con = PostgreSQLConnection(host='172.17.0.2',database='work',user='postgres',password='123')
con.connect()
# Out:
# Connected to the PostgreSQL database

# %%
# Define the SQL query to retrieve data from the table
sql_query = "SELECT * FROM jobs"

# Read the table data into a Pandas DataFrame
df = pd.read_sql(sql_query, con.connection)

# Close the database connection
con.close()
# Out:
# Connection to PostgreSQL closed
# /tmp/ipykernel_33646/349984639.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql_query, con.connection)

# %%
df.head()
# Out:
#                                  id                    job_titile  \
# 0  9b4aaf84806b64bdfba25cfd8524a9c0       Investment Data Analyst
# 1  fd7b8be19989998633bc7413bf87e5e0  Master Data Business Analyst
# 2  de305302e0468c6e6b40fb9fe0bd48b6    Data Analyst, Monetization
# 3  36863de4a6b1972ea55bfd80cfd6f217         Senior / Data Analyst
# 4  42c13ab162229957a69cf418ea714d9c                  Data Analyst
#
#            job_location                                    job_description  \
# 0    Bukit Merah Estate  We’re looking for an investment data analyst, ...
# 1  Jurong East New Town  Job Description\nResponsible for understanding...
# 2             Singapore  ByteDance will be prioritizing applicants who ...
# 3             Singapore  Summary\nSalary:\nCompetitive\nTeam:\nData Ana...
# 4             Singapore  Data Engineering & Analytics\nFull Time\nExecu...
#
#                          company_name company_founde       company_type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 484 entries, 0 to 483
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                484 non-null    object
#  1   job_titile        484 non-null    object
#  2   job_location      484 non-null    object
#  3   job_description   484 non-null    object
#  4   company_name      484 non-null    object
#  5   company_founde    484 non-null    object
#  6   company_type      484 non-null    object
#  7   company_industry  484 non-null    object
#  8   company_sector    484 non-null    object
#  9   company_revenue   484 non-null    object
#  10  stars             484 non-null    float64
#  11  company_size      406 non-null    float64
#  12  min_salary        305 non-null    float64
#  13  max_salary        280 non-null    float64
# dtypes: float64(4), object(10)
# memory usage: 53.1+ KB

# %%
df[(df['min_salary'].isna() & (~df['max_salary'].isna()))]
# Out:
# Empty DataFrame
# Columns: [id, job_titile, job_location, job_description, company_name, company_founde, company_type, company_industry, company_sector, company_revenue, stars, company_size, min_salary, max_salary]
# Index: []

# %%
df[(~df['min_salary'].isna() & df['max_salary'].isna())].head()
# Out:
#                                   id  \
# 12  fc8e97e34b63878f3227396746aeed7d
# 21  8cc300bf8bd0e4b86c4bfe27df38248a
# 24  e527f2a15e8d63953b0001a3b8df43ac
# 56  adfb41b666987b2ea2e3b8526c8b8305
# 65  62ddf6969ace14c119d71ee27f61295f
#
#                                   job_titile job_location  \
# 12  G1000 Accelerated Program (Data Analyst)    Singapore
# 21                       Junior Data Analyst    Singapore
# 24                         Data Analyst (CAT    Singapore
# 56    Supply Chain Data Analyst (Internship)    Singapore
# 65                       Junior Data Analyst    Singapore
#
#                                       job_description  \
# 12  Company\nDHL Supply Chain\ndhl.com\nDesignatio...
# 21  Job Information\nIndustry\nManufacturing\nSala...
# 24  Job Information\nIndustry\nBanking\nSalary\n80...
# 56  The Supply Chain Data Analyst blends historica...
# 65  Key Requirements:\n\nWe are looking for Junior...
#
# ...

# %%
df.loc[(~df['min_salary'].isna() & df['max_salary'].isna()), 'max_salary'] = df['min_salary']

# %%
df[(~df['min_salary'].isna() & df['max_salary'].isna())].head()
# Out:
# Empty DataFrame
# Columns: [id, job_titile, job_location, job_description, company_name, company_founde, company_type, company_industry, company_sector, company_revenue, stars, company_size, min_salary, max_salary]
# Index: []

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 257 entries, 0 to 481
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                257 non-null    object
#  1   job_titile        257 non-null    object
#  2   job_location      257 non-null    object
#  3   job_description   257 non-null    object
#  4   company_name      257 non-null    object
#  5   company_founde    257 non-null    object
#  6   company_type      257 non-null    object
#  7   company_industry  257 non-null    object
#  8   company_sector    257 non-null    object
#  9   company_revenue   257 non-null    object
#  10  stars             257 non-null    float64
#  11  company_size      257 non-null    float64
#  12  min_salary        257 non-null    float64
#  13  max_salary        257 non-null    float64
# dtypes: float64(4), object(10)
# memory usage: 30.1+ KB

# %%
df.head()
# Out:
#                                  id                      job_titile  \
# 0  9b4aaf84806b64bdfba25cfd8524a9c0         Investment Data Analyst
# 2  de305302e0468c6e6b40fb9fe0bd48b6      Data Analyst, Monetization
# 7  af1d50f7ff5403f74da0498db3bb15ad  Social Media Data Analyst APAC
# 8  29b4e651fd17d2eca74c25dc9806e6a5  Data Business Analyst (IFRS17)
# 9  4456861182f130cc2a6bdfc8bdbc3f3f                Business Analyst
#
#          job_location                                    job_description  \
# 0  Bukit Merah Estate  We’re looking for an investment data analyst, ...
# 2           Singapore  ByteDance will be prioritizing applicants who ...
# 7           Singapore  Brandwatch is the world’s premier social suite...
# 8           Singapore  We are looking to build a team of Data Busines...
# 9           Serangoon  Job Summary:\nWorks closely with business part...
#
#                company_name company_founde       company_type  \
# ...
